# %%
import pandas as pd

# %%
import numpy as np

# %%
location = "extracted/datasets/DC_Properties.csv"
df = pd.read_csv(location)
df.head(8)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (18,19,20,21,22,23,24,33,34,35,37,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
# 5           5       3          2  Hot Water Rad  Y        1.0     10      5
# 6           6       1          0      Warm Cool  Y        2.0      5      2
# 7           7       3          1  Hot Water Rad  Y        2.0      8      4
#
# ...

# %%
df.tail(3)
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM        HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 158954      158954       2          0  Forced Air  Y        NaN      4      2
# 158955      158955       1          0   Warm Cool  Y        NaN      2      0
# 158956      158956       1          0   Warm Cool  Y        NaN      2      0
#
#            AYB  YR_RMDL   ...     LONGITUDE       ASSESSMENT_NBHD  \
# 158954  1920.0   2007.0   ...     -77.01942            Old City 2
# 158955  1965.0      NaN   ...     -77.01823  Southwest Waterfront
# 158956  1965.0      NaN   ...     -77.01823  Southwest Waterfront
#
#        ASSESSMENT_SUBNBHD  CENSUS_TRACT CENSUS_BLOCK    WARD  SQUARE  \
# 158954   040 B Old City 2        4801.0          NaN  Ward 6     477
# 158955                NaN       11000.0          NaN  Ward 6     504
# 158956                NaN       11000.0          NaN  Ward 6     504
#
#                 X          Y QUADRANT
# 158954 -77.019422  38.911848       NW
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS',
#        'BEDRM', 'AYB', 'YR_RMDL', 'EYB', 'STORIES', 'SALEDATE', 'PRICE',
#        'QUALIFIED', 'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE',
#        'CNDTN', 'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES',
#        'USECODE', 'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM',
#        'LIVING_GBA', 'FULLADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID',
#        'LATITUDE', 'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD',
#        'CENSUS_TRACT', 'CENSUS_BLOCK', 'WARD', 'SQUARE', 'X', 'Y', 'QUADRANT'],
#       dtype='object')

# %%
dupe = df.duplicated() #creates list of True/False values
df[dupe] #shows rows where duplicated is True
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, BATHRM, HF_BATHRM, HEAT, AC, NUM_UNITS, ROOMS, BEDRM, AYB, YR_RMDL, EYB, STORIES, SALEDATE, PRICE, QUALIFIED, SALE_NUM, GBA, BLDG_NUM, STYLE, STRUCT, GRADE, CNDTN, EXTWALL, ROOF, INTWALL, KITCHENS, FIREPLACES, USECODE, LANDAREA, GIS_LAST_MOD_DTTM, SOURCE, CMPLX_NUM, LIVING_GBA, FULLADDRESS, CITY, STATE, ZIPCODE, NATIONALGRID, LATITUDE, LONGITUDE, ASSESSMENT_NBHD, ASSESSMENT_SUBNBHD, CENSUS_TRACT, CENSUS_BLOCK, WARD, SQUARE, X, Y, QUADRANT]
# Index: []
#
# [0 rows x 49 columns]

# %%
df.drop_duplicates()
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 0                0       4          0      Warm Cool  Y        2.0      8
# 1                1       3          1      Warm Cool  Y        2.0     11
# 2                2       3          1  Hot Water Rad  Y        2.0      9
# 3                3       3          1  Hot Water Rad  Y        2.0      8
# 4                4       2          1      Warm Cool  Y        1.0     11
# 5                5       3          2  Hot Water Rad  Y        1.0     10
# 6                6       1          0      Warm Cool  Y        2.0      5
# 7                7       3          1  Hot Water Rad  Y        2.0      8
# 8                8       3          1      Warm Cool  Y        2.0      7
# 9                9       1          1  Hot Water Rad  Y        1.0      6
# 10              10       3          0     Forced Air  N        3.0     12
# 11              11       5          0  Hot Water Rad  Y        3.0     16
# ...

# %%
df.drop_duplicates(['Names'], keep='last')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Names'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-e7d1257af89b> in <module>()
# ...

# %%
filename = "datasets/filename = "datasets/gradedatamissing.csv"
df_missing = pd.read_csv(filename)"
# Out:
#   File "<ipython-input-15-1a1c09c1e17a>", line 1
#     filename = "datasets/filename = "datasets/gradedatamissing.csv"
#                                             ^
# SyntaxError: invalid syntax

# %%
filename = "datasets/DC_ Properties.csv"
df_missing = pd.read_csv(filename)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-c2b2d373b480> in <module>()
#       1 filename = "datasets/DC_ Properties.csv"
# ----> 2 df_missing = pd.read_csv(filename)
#
# ...

# %%
filename = "extracted/datasets/DC_Properties.csv"
df_missing = pd.read_csv(filename)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (18,19,20,21,22,23,24,33,34,35,37,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_missing.isnull().sum()
# Out:
# Unnamed: 0                 0
# BATHRM                     0
# HF_BATHRM                  0
# HEAT                       0
# AC                         0
# NUM_UNITS              52261
# ROOMS                      0
# BEDRM                      0
# AYB                      271
# YR_RMDL                78029
# EYB                        0
# STORIES                52305
# SALEDATE               26770
# PRICE                  60741
# QUALIFIED                  0
# SALE_NUM                   0
# GBA                    52261
# BLDG_NUM                   0
# STYLE                  52261
# STRUCT                 52261
# GRADE                  52261
# CNDTN                  52261
# EXTWALL                52261
# ROOF                   52261
# INTWALL                52261
# KITCHENS               52262
# FIREPLACES                 0
# USECODE                    0
# LANDAREA                   0
# GIS_LAST_MOD_DTTM          0
# SOURCE                     0
# CMPLX_NUM             106696
# ...

# %%
df_no_missing = df.dropna()
df_no_missing
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, BATHRM, HF_BATHRM, HEAT, AC, NUM_UNITS, ROOMS, BEDRM, AYB, YR_RMDL, EYB, STORIES, SALEDATE, PRICE, QUALIFIED, SALE_NUM, GBA, BLDG_NUM, STYLE, STRUCT, GRADE, CNDTN, EXTWALL, ROOF, INTWALL, KITCHENS, FIREPLACES, USECODE, LANDAREA, GIS_LAST_MOD_DTTM, SOURCE, CMPLX_NUM, LIVING_GBA, FULLADDRESS, CITY, STATE, ZIPCODE, NATIONALGRID, LATITUDE, LONGITUDE, ASSESSMENT_NBHD, ASSESSMENT_SUBNBHD, CENSUS_TRACT, CENSUS_BLOCK, WARD, SQUARE, X, Y, QUADRANT]
# Index: []
#
# [0 rows x 49 columns]

# %%
df2=df[['BEDRM', 'BATHRM', 'GBA', 'STYLE', 'PRICE', 'WARD', 'AYB', 'SALEDATE']]

# %%
df2=df[['BEDRM', 'BATHRM', 'GBA', 'STYLE', 'PRICE', 'WARD', 'AYB', 'SALEDATE']]
df2.head()
# Out:
#    BEDRM  BATHRM     GBA    STYLE      PRICE    WARD     AYB  \
# 0      4       4  2522.0  3 Story  1095000.0  Ward 2  1910.0
# 1      5       3  2567.0  3 Story        NaN  Ward 2  1898.0
# 2      5       3  2522.0  3 Story  2100000.0  Ward 2  1910.0
# 3      5       3  2484.0  3 Story  1602000.0  Ward 2  1900.0
# 4      3       2  5255.0  3 Story        NaN  Ward 2  1913.0
#
#               SALEDATE
# 0  2003-11-25 00:00:00
# 1  2000-08-17 00:00:00
# 2  2016-06-21 00:00:00
# 3  2006-07-12 00:00:00
# 4                  NaN

# %%
df2.groupby(['BEDRM', 'WARD']).mean()
# Out:
#                  BATHRM           GBA         PRICE          AYB
# BEDRM WARD
# 0     Ward 1   1.003356   1472.181818  4.374085e+05  1944.447987
#       Ward 2   1.001099   2306.285714  1.063929e+06  1955.212532
#       Ward 3   1.002275    750.625000  8.533485e+06  1962.099089
#       Ward 4   1.023256   1286.000000  2.534351e+05  1934.093023
#       Ward 5   1.036697   1460.345455  2.259893e+05  1935.407407
#       Ward 6   1.000000   1535.380952  2.346078e+05  1957.449173
#       Ward 7   0.896552   1019.785714  3.995500e+05  1941.821429
#       Ward 8   1.281250   1411.377358  2.426689e+06  1943.241935
# 1     Ward 1   1.071223   1102.562500  5.299856e+05  1947.774954
#       Ward 2   1.062225   1016.284091  1.012982e+06  1963.786424
#       Ward 3   1.026164   1542.318182  7.120841e+06  1957.178145
#       Ward 4   1.015403   1501.562500  3.366974e+05  1943.906810
#       Ward 5   1.022246   1155.000000  2.355410e+05  1946.711559
# ...

# %%
df2('PRICE'.dropna(axis=0,how='all')]
# Out:
#   File "<ipython-input-37-a5942aca6c82>", line 1
#     df2('PRICE'.dropna(axis=0,how='all')]
#                                         ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Number'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-8b13df4d653b> in <module>()
# ...

# %%
sns.lmplot(x='PRICE', y='BATHRM', data=df)
